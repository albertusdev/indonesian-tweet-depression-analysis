# %%
import twint

# %%
c = twint.Config()

# %%
c.Limit = 50
c.Search = "pengen bunuh diri"
c.Store_csv = True
c.Output = "negative_tweet_albert"

# %%
twint.run.Search(c)
# Out:
# -------------------------------------
# RuntimeErrorTraceback (most recent call last)
# <ipython-input-5-f28f8e9aab1e> in <module>
# ----> 1 twint.run.Search(c)
#
# ~/src/twint/twint/run.py in Search(config, callback)
#     269     config.Profile = False
#     270     config.Profile_full = False
# --> 271     run(config, callback)
#     272     if config.Pandas_au:
#     273         storage.panda._autoget("tweet")
#
# ~/src/twint/twint/run.py in run(config, callback)
#     198 def run(config, callback=None):
#     199     logme.debug(__name__+':run')
# --> 200     get_event_loop().run_until_complete(Twint(config).main(callback))
#     201
#     202 def Favorites(config):
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.7/asyncio/base_events.py in run_until_complete(self, future)
#     569         future.add_done_callback(_run_until_complete_cb)
#     570         try:
# --> 571             self.run_forever()
#     572         except:
# ...

# %%
twint.output.tweets_object
# Out:
# []

# %%
tweets
# Out:
# -------------------------------------
# NameErrorTraceback (most recent call last)
# <ipython-input-7-57fc2c7c7187> in <module>
# ----> 1 tweets
#
# NameError: name 'tweets' is not defined

# %%
import pandas as pd
pd = pd.read_csv("dataset/tweets.csv")

# %%
pd.columns
# Out:
# Index(['id', 'conversation_id', 'created_at', 'date', 'time', 'timezone',
#        'user_id', 'username', 'name', 'place', 'tweet', 'mentions', 'urls',
#        'photos', 'replies_count', 'retweets_count', 'likes_count', 'location',
#        'hashtags', 'link', 'retweet', 'quote_url', 'video',
#        'profile_image_url'],
#       dtype='object')

# %%
pd.drop(['id', 'conversation_id', 'mentions', 'photos',], axis=1, inplace=True)

# %%
pd
# Out:
#         created_at        date      time timezone              user_id  \
# 0    1544672256000  2018-12-13  10:37:36      WIB            575220756
# 1    1544633395000  2018-12-12  23:49:55      WIB  1019211514190761985
# 2    1544619663000  2018-12-12  20:01:03      WIB           2663778276
# 3    1544617325000  2018-12-12  19:22:05      WIB  1006835643572367360
# 4    1544601448000  2018-12-12  14:57:28      WIB           2180457680
# 5    1544592988000  2018-12-12  12:36:28      WIB            395766243
# 6    1544585300000  2018-12-12  10:28:20      WIB           2407380116
# 7    1544583757000  2018-12-12  10:02:37      WIB  1063312291716726784
# 8    1544568643000  2018-12-12  05:50:43      WIB            526645012
# 9    1544553811000  2018-12-12  01:43:31      WIB            243893129
# 10   1544545376000  2018-12-11  23:22:56      WIB             84749201
# 11   1544509905000  2018-12-11  13:31:45      WIB  1061946709444517888
# ...
